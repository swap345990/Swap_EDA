# %% [markdown]
# ### Variables

# %%
# to store the value

# varyyyyyyyyyyyyy

# It can also change

# %%
a=10
a

# 10 is a vlaue stored in a variable a
# Out:
# 10

# %%
a=20
a

# 20 is a value stored in a variable a
# Out:
# 20

# %%
number=100
number
# Out:
# 100

# %%
NUMBER=200
NUMBER
# Out:
# 200

# %%
number,NUMBER
# Out:
# (100, 200)

# %%
NUMber=300
NUMber
# Out:
# 300

# %%
Num123=400
Num123
# Out:
# 400

# %%
123num=500
123num
# Out:
#   Cell In[9], line 1
#     123num=500
#       ^
# SyntaxError: invalid decimal literal

# %%
500=600
# Out:
#   Cell In[10], line 1
#     500=600
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
number$=700
number$
# Out:
#   Cell In[11], line 1
#     number$=700
#           ^
# SyntaxError: invalid syntax

# %%
number=$700
# Out:
#   Cell In[12], line 1
#     number=$700
#            ^
# SyntaxError: invalid syntax

# %%
number@hello=800
number@hello
# Out:
#   Cell In[13], line 1
#     number@hello=800
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
number_=900
number_
# Out:
# 900

# %%
_=1000
_
# Out:
# 1000

# %%
sum=900
sum
# Out:
# 900

# %%
in python green colour means keywords
math keywords works,remaining all other keywords fail

# %%
max=600
max
# Out:
# 600

# %%
if=900
# Out:
#   Cell In[18], line 1
#     if=900
#       ^
# SyntaxError: invalid syntax

# %%
for=800
# Out:
#   Cell In[19], line 1
#     for=800
#        ^
# SyntaxError: invalid syntax

# %%
sum=900

# %%
SUM=900

# %%
AGE=30
AGE
age=50
age

AGE,age
# Out:
# (30, 50)

# %% [markdown]
# - Balck colour: variables
#
# - Variables can be upper case: NUMBER
#
# - Variables can be lower case : number
#
# - Variables can be combination of Upperand Lower : NUMber
#
# - Letters and Numbers as suffix combination works: number123
#
# - undescore can use as variables
#
# - Numbers as prefix is invalid: 123number
#
# - spaces , spl charcaters ,symbols are invalid : number$, number@
#
# - Green color: keywords
#
# - Other than math keywords are in valid
#
# - sum max min math keywords

# %%
number one=200
# Out:
#   Cell In[24], line 1
#     number one=200
#            ^
# SyntaxError: invalid syntax

# %%
number_one=200
