# %%
file_path="emails.txt"
with open(file_path,mode='r',encoding='utf-8-sig') as file:
    s=[i.split(';') for i in file]
for v in s:
    pass
for j in range(len(v)):
    out=v[j].lstrip()
    #print(out)
    print(j,out[:out.find(",")],"*",out[out.find(",")+1:out.find("<")-1],"*",out[out.find("<")+1:out.find(">")],"*",out[out.find("@")+1:out.find(".",out.find(".")+1)])
# Out:
# 0 Santhanam *  Jayendhran * jayendhran.ms@accenture.com * accenture
# 1 Bhattacharjee *  Sankalan * s.t.bhattacharjee@accenture.com *
# 2 Bansal *  Vaishnavi * vaishnavi.a.bansal@accenture.com *
# 3 Chandra Shekhar *  Pavuluri * p.a.chandra.shekhar@accenture.com *
# 4 J Doshi *  Hiren * hiren.j.doshi@accenture.com *
# 5 Shimoga Prakash *  Jeevan * j.shimoga.prakash@accenture.com *
# 6 Akhouri *  Shreyash * shreyash.akhouri@accenture.com * accenture
# 7 Nath *  Nupanga * nupanga.nath@accenture.com * accenture
# 8 Ponna *  Ramesh * r.ponna@accenture.com * accenture
# 9 Singhal *  Aditya * aditya.d.singhal@accenture.com *
# 10 Gorai *  Sumit * sumit.gorai@accenture.com * accenture
# 11 Valdez *  Mariele Dyan Francely * mariele.dyan.valdez@accenture.com *
# 12 Cancel *  Abigail Kyle * abigail.kyle.cancel@accenture.com *
# 13 BONDALAKUNTA *  POOJITHA * p.bondalakunta@accenture.com * accenture
# 14 priyanka uppala *  sai * sai.priyanka.uppala@accenture.com *
# ...

# %%
acc_bal=200
e_wall=5000
while acc_bal<1000:
    print("You still dont have enough money to start playing")
    d=eval(input("withdraws money form wallet: "))
    acc_bal=acc_bal+d
    e_wall=e_wall-d
    print("your account balance is",acc_bal)
    print("your e_wallet balance is",e_wall)
print("now you are ready to play game")
#     if acc_bal==1000:
#         print("now play ready to game")
#     else:
#         print(d)
# Out:
# You still dont have enough money to start playing
# withdraws money form wallet: 500
# your account balance is 700
# your e_wallet balance is 4500
# You still dont have enough money to start playing
# withdraws money form wallet: 300
# your account balance is 1000
# your e_wallet balance is 4200
# now you are ready to play game
