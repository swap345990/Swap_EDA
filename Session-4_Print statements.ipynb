# %%
Variables

packages

import <package_name>
dir(package name) ===== methods
help(<package_name>.<method_name>)
<package_name>.<method_name>()

# %%
import random

# %%
len(dir(random))
# Out:
# 66

# %% [markdown]
# **Print statements**

# %%
num=100
print(num)
# Out:
# 100

# %%
print("hello")
# Out:
# hello

# %%
print(hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(hello)
#
# NameError: name 'hello' is not defined

# %% [markdown]
# - whenever you see name error: Name not defined
#
# - you need to check above lines , is that variable initialized or not?

# %%
print("hello","python")
# Out:
# hello python

# %%
print("hello python")
# Out:
# hello python

# %%
print(1,2,3,4,5)
# Out:
# 1 2 3 4 5

# %%
print(12345)
# Out:
# 12345

# %%
name1="hello"
name2="python"
print(name1,name2)
# Out:
# hello python

# %%
a=10
b=20
c=a+b
print("the value of 10 and 20 is 30")
# Out:
# the value of 10 and 20 is 30

# %%
a=10
b=20
c=a+b
print("the value of a and b is c")
# Out:
# the value of a and b is c

# %%
a=10
b=20
c=a+b
print("the value of",a,"and",b,'is',c)
# Out:
# the value of 10 and 20 is 30

# %%
#Should we add a “ “ after and before variables?
#english words : strings
    
"saimha"   # it is a string

# %%
print("The value of", a," …..")
# Out:
# The value of 10  …..

# %%
print('hello')
print("python")
# Out:
# hello
# python

# %%
# write your name in a name variable
# write your age  in a age variable 
# write your city in a city variable
# o/p:Im <name> Im from <city> Im <age> years old

name="charan"
age=25
city="hyd"
print("I am",name,"I am from",city,"I am",age,"years old")
# Out:
# I am charan I am from hyd I am 25 years old

# %%
#################### BAD WAY of writing############
a=10
b=20
c=a+b
print("the value of",a,"and",b,'is',c)

# %% [markdown]
# $format$

# %%
a=10
b=20
c=a+b
print("the value of {} and {} is {}".format(a,b,c))
# Out:
# the value of 10 and 20 is 30

# %%
name="charan"
age=25
city="hyd"
print("I am",name,"I am from",city,"I am",age,"years old")
print("I am {} I am from {} I am {} years old".format(name,city,age))
# Out:
# I am charan I am from hyd I am 25 years old
# I am charan I am from hyd I am 25 years old

# %% [markdown]
# $f$ $string$

# %%
a=10
b=20
c=a+b
print(f"the value of {a} and {b} is {c}")
# Out:
# the value of 10 and 20 is 30

# %%
a=10
b=20
c=a+b
print("the value of",a,"and",b,'is',c)
print("the value of {} and {} is {}".format(a,b,c))
print(f"the value of {a} and {b} is {c}") # Qulaity
# Out:
# the value of 10 and 20 is 30
# the value of 10 and 20 is 30
# the value of 10 and 20 is 30

# %%
name="charan"
age=25
city="hyd"
print("I am",name,"I am from",city,"I am",age,"years old")
print("I am {} I am from {} I am {} years old".format(name,city,age))
print(f"I am {name} I am from {city} I am {age} years old")
# Out:
# I am charan I am from hyd I am 25 years old
# I am charan I am from hyd I am 25 years old
# I am charan I am from hyd I am 25 years old

# %% [markdown]
# - normal print
#
# - .format
#
# - f string

# %% [markdown]
# $end$

# %%
print('hello',end=" ")
print('python')

# hello python
# i want to join hello with python
# how you want join together
# Out:
# hello python

# %%
# I want to join multiple print statements
print(1,end=" ")
print(2,end=" ")
print(3)

# 1 2 3
# Out:
# 1 2 3

# %%
a=1
b=2
c=3
print(f"the sum of {a} and {b} is {c}")
# Out:
# the sum of 1 and 2 is 3
