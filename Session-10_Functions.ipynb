# %%
print("hello raja")
print("hello asrar")
print("hello danish")

# %%
if you want to run a piece of code multiple times

if you want to use a piece of code multiple times

if you call a piece of code multiple times

functions

# %%
num1=10
num2=20
add=num1+num2
print("the addition of {} and {} is {}".format(num1,num2,add))
# Out:
# the addition of 10 and 20 is 30

# %%
print
input
import
eval
if 
else
elif
try
except 
def
type

# %%
def <function_name>():
    ###########
    task
    ##########

# %% [markdown]
# ### 1.Function with out arguments

# %%
def addition():
    num1=10
    num2=20
    print(num1+num2)

# %% [markdown]
# - if you run the function creation code it will not give the any output
#
# - if you want to run that function , you need to call the function
#
# - will not get any error and any output untill unless we call the function

# %%
addition()
# Out:
# 30

# %%
def greet():
    print('hai')
    print('hello')
    
greet()
# Out:
# hai
# hello

# %%
greet()
# Out:
# hai
# hello

# %%
greet()
# Out:
# hai
# hello

# %%
print(1)
print(2)
greet()
print('done')
# Out:
# 1
# 2
# hai
# hello
# done

# %%
def addition1():
    num1=10
    num2=20
    print(num11+num2)

# %%
addition1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 addition1()
#
# Cell In[12], line 4, in addition1()
#       2 num1=10
#       3 num2=20
# ----> 4 print(num11+num2)
#
# NameError: name 'num11' is not defined

# %%
# Create a function name with average
# ask the user enter three numbers
#   n1=eval(input())
#   n2=eval(input())
#   n3=eval(input())
#   average= (n1+n2+n3)/3
#   print(average)

# %%
- Function is like a wrapper

- we develop a normal code

- But this code will execute by a function call

# %%
n1=20
n2=30
n3=40
add=n1+n2+n3
avg=round(add/3,2)
print("The average of {}, {} and {} is {}".format(n1,n2,n3,avg))
print(f"The average of {n1}, {n2} and {n3} is {avg}")
# Out:
# The average of 20, 30 and 40 is 30.0
# The average of 20, 30 and 40 is 30.0

# %%
def average():
    n1=20
    n2=30
    n3=40
    add=n1+n2+n3
    avg=round(add/3,2)
    print("The average of {}, {} and {} is {}".format(n1,n2,n3,avg))
    print(f"The average of {n1}, {n2} and {n3} is {avg}")
    
# function is ready

# %%
average()
# they are not using print statements
# they are feeling tht i'm not getting output
# their function name inside some variable names alos mentioning same name
# make sure that function name and variable names should be different
# Out:
# The average of 20, 30 and 40 is 30.0
# The average of 20, 30 and 40 is 30.0

# %%
# if you want to implment try-exception
# implement inside the function call
# try-except both should be align
def average():
    try:
        n1=20
        n2=30
        n3=40
        add=n1+n2+n3
        avg=round(add/0,2)
        print("The average of {}, {} and {} is {}".format(n1,n2,n3,avg))
        print(f"The average of {n1}, {n2} and {n3} is {avg}")
        
    except Exception as e:
        print(e)

average()
# Out:
# division by zero

# %%
def average1():
    try:
        n1=eval(input("enter the number1:"))
        n2=eval(input("enter the number2:"))
        n3=eval(input("enter the number3:"))
        add=n1+n2+n3
        avg=round(add/3,2)
        print("The average of {}, {} and {} is {}".format(n1,n2,n3,avg))
        print(f"The average of {n1}, {n2} and {n3} is {avg}")
        
    except Exception as e:
        print(e)

average1()
# Out:
# enter the number1:30
# enter the number240
# enter the number3:50
# The average of 30, 40 and 50 is 40.0
# The average of 30, 40 and 50 is 40.0

# %%
# WAP create the average function by taking values randomly
import random
def average2():
    try:
        n1=random.randint(1,20)
        n2=random.randint(1,20)
        n3=random.randint(1,20)
        add=n1+n2+n3
        avg=round(add/3,2)
        print("The average of {}, {} and {} is {}".format(n1,n2,n3,avg))
        print(f"The average of {n1}, {n2} and {n3} is {avg}")
        
    except Exception as e:
        print(e)

average2()
# Out:
# The average of 14, 7 and 18 is 13.0
# The average of 14, 7 and 18 is 13.0

# %%
n1=30
n1=eval(input())
n1=random.randint(1,20)

#####################################################
n1=20
n2=30
n3=40
add=n1+n2+n3
avg=round(add/3,2)
######################################################
n1=eval(input("enter the number1:"))
n2=eval(input("enter the number2:"))
n3=eval(input("enter the number3:"))
add=n1+n2+n3
avg=round(add/3,2)
#######################################################
n1=random.randint(1,20)
n2=random.randint(1,20)
n3=random.randint(1,20)
add=n1+n2+n3
avg=round(add/3,2)

# %%
import random
def average1():    
    try:
        n1=random.randint(1,20)
        n2=random.randint(1,20)
        n3=random.randint(1,20)
        add=n1+n2+n3
        avg=(add/0)
        print('the average of {},{},{} is {}'.format(n1,n2,n3,avg))
    except Exception as e:
        print('Exception {}'.format(e))
average1()
# Out:
# Exception division by zero

# %%
# WAP ask the user enter bill amount
#     ask the user how much tip percentage you want to provide
#     calculate the total bil
# create a function and call it

# %%
# Normal code
bill=eval(input("enter the bill:"))
tip_per=eval((input("enter the tip in %:")))
tip_amount=bill*tip_per/100
total_bill=bill+tip_amount
print("The total bill is:",total_bill)
# Out:
# enter the bill:1000
# enter the tip in %:10
# The total bill is: 1100.0

# %%
def restro():
    bill=eval(input("enter the bill:"))
    tip_per=eval((input("enter the tip in %:")))
    tip_amount=bill*tip_per/100
    total_bill=bill+tip_amount
    print("The total bill is:",total_bill)
    
restro()
# Out:
# enter the bill:2000
# enter the tip in %:10
# The total bill is: 2200.0

# %%
def restro():
    try:
        bill=eval(input("enter the bill:"))
        tip_per=eval((input("enter the tip in %:")))
        tip_amount=bill*tip_per/100
        total_bill=bill+tip_amount
        print("The total bill is:",total_bill)
        
    except Exception as e:
        print(e)
    
restro()
# Out:
# enter the bill:2000
# enter the tip in %:20
# The total bill is: 2400.0

# %%
# wap ask the user enter a number find wether it is an even or odd
# take numbers randomly also

# Normal code
# step-1: num=eval(input("enter "))
# step-2: if <condition>:
# step-3:     print("even")
# step-4: else:
# step-5:    print("odd")


print(f"{number} is even")
# Out:
# number is even

# %%
num=eval(input("enter a number:"))
if num%2==0:
    print("{} is even".format(num))
    print(f"{num} is even")
    print("even number:",num)
else:
    print("{} is odd".format(num))
    print(f"{num} is odd")
    print("odd number:",num)
# Out:
# enter a number:11
# 11 is odd
# 11 is odd
# odd number: 11

# %%
# Dont equal function name, and variable name
def even_odd():
    num=eval(input("enter a number:"))
    if num%2==0:
        print("{} is even".format(num))
        print(f"{num} is even")
        print("even number:",num)
    else:
        print("{} is odd".format(num))
        print(f"{num} is odd")
        print("odd number:",num)

even_odd()
# Out:
# enter a number:23
# 23 is odd
# 23 is odd
# odd number: 23

# %%
def even_odd1():
    start=eval(input("provide the start value:"))
    last=eval(input("provide the last value"))
    num=random.randint(start,last)
    if num%2==0:
        print("{} is even".format(num))
        print(f"{num} is even")
        print("even number:",num)
    else:
        print("{} is odd".format(num))
        print(f"{num} is odd")
        print("odd number:",num)

even_odd1()
# Out:
# provide the start value:300
# provide the last value400
# 335 is odd
# 335 is odd
# odd number: 335

# %%
add()
average()
restro()
even_odd()

# every function has brackets
# if you pass anything inside brackets we called arguments or parameters

# %%
im not provided anyting inside my function

**Function with out arguements**

# %% [markdown]
# ### 2.Function with arguments or parameters

# %% [markdown]
# - In your original code how many variable are there
#
# - In your original code how many input variables are there
#
# - In your original code how many output variable are there
#
# - Output variable create by using input variable
#
# - whenever you want create function with argument only concentrate input variable
#
# - provide the values while calling the function

# %%
def addition():
    num1=10
    num2=20
    add=num1+num2
    print(add)
    
addition()

# q1) How many 3:  num1  num2  add
# q2) how many i/p: num1 and num2
# q3) how many output: add
# Out:
# 30

# %%
def addition(num1,num2):
    add=num1+num2
    print(add)
    
addition(10,20)
# Out:
# 30

# %%
# Create a function with arguments for average program

# %%
def average1(n1,n2,n3):
    try:
        add=n1+n2+n3
        avg=round(add/3,2)
        print("The average of {}, {} and {} is {}".format(n1,n2,n3,avg))
        print(f"The average of {n1}, {n2} and {n3} is {avg}")
        
    except Exception as e:
        print(e)

average1(10,20,30)

#q1) 5   i(3) + o(2)
# Out:
# The average of 10, 20 and 30 is 20.0
# The average of 10, 20 and 30 is 20.0

# %%
# Bill payment
# Even_odd

# whatsapp group

# s
