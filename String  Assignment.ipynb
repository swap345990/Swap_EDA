# %%
str1=input("enter the word:   ")
a=len(str1)

for i in range(1,11):
    print(i,str1)
c=str1[0]
d=str1[:3]
e=str1[len(str1)-3:]
f=str1[::-1]
g=str1[7]
h=str1[1:-1]
i=str1.upper()
j=str1.replace("a","e")

print(f"lenth of word is {a}")
print(f"first character of string is {c}")
print(f"first three character of string is {d}")
print(f"last three charcter of string is {e}")
print(f)
print(g)
print(h)
print(i)
print(j)
# Out:
# enter the word:   my name is swapneswar sahoo
# 1 my name is swapneswar sahoo
# 2 my name is swapneswar sahoo
# 3 my name is swapneswar sahoo
# 4 my name is swapneswar sahoo
# 5 my name is swapneswar sahoo
# 6 my name is swapneswar sahoo
# 7 my name is swapneswar sahoo
# 8 my name is swapneswar sahoo
# 9 my name is swapneswar sahoo
# 10 my name is swapneswar sahoo
# lenth of word is 27
# first character of string is m
# first three character of string is my
# last three charcter of string is hoo
# oohas rawsenpaws si eman ym
#
# y name is swapneswar saho
# MY NAME IS SWAPNESWAR SAHOO
# my neme is swepneswer sehoo

# %%
str2=input("enter the string:")
count=0
for i in str2:
    if i in " ":
        count=count+1
print(f"the number of word is {count}")
# Out:
# enter the string:my name is swapneswar sahoo
# the number of word is 4

# %%
def containsVowels():
    #string = string.lower()
    for char in v:
        if char in "aeiou":
           return "contains vowel"
    return "not vowel"
v=input("enter the word:")
print(containsVowels())
# Out:
# enter the word:kljkl
# not vowel

# %%
str4=input("enter the word: ")

vs="aeiou"
vt=""
for i in vs:
    if i in str4 and i not in vt:
        
        print(i,end="")
print()
# Out:
# enter the word: swapneswar
# ae

# %%
str5=input("enter the word: ")
addd="!!!"
ff=str5[0].capitalize()
jj="*"
rest=str5[1:]
new_str=ff+jj+rest+addd
new_str
# Out:
# enter the word: swapneswar
# 'S*wapneswar!!!'

# %%
str6=input("enter the String:  ")

for i in str6:
    print(i.capitalize()*2)
# Out:
# enter the String:  swap
# SS
# WW
# AA
# PP

# %%
str7=input("enter the word;  ")
first=str7[:len(str7)-2]
second=str7[len(str7)-2:]
print(first)
print(second)
# Out:
# enter the word;  swapneswar
# swapnesw
# ar

# %%
str7=input("enter the number:  ")
cc=""
for i in range(len(str7)):
    if i%2:
        cc=cc+str7[i].upper()
        str7[i]
    else:
        cc=cc+str7[i].lower()
        
print(cc)
# Out:
# enter the number:  swapneswar
# sWaPnEsWaR

# %%
def check_vo():
    for i in word:
        print(i)
        if i in "aeiou":
            return "contains vowel"
    return "not vowel"
word=input("enter the word: ")
op=check_vo()
print(op)
# Out:
# enter the word: jjkkh
# j
# j
# k
# k
# h
# not vowel
